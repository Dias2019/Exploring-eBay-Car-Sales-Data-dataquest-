# %% [markdown]
# # Exploring Ebay Car Sales Data

# %% [markdown]
# This project is about smth

# %% [markdown]
# Also about this project

# %% [markdown]
# Firstly, we start by importing all the necessary libraries to carry out our project.

# %%
import pandas as pd
import numpy as np

# %%
autos = pd.read_csv("autos.csv", encoding='Latin-1')

# %%
autos
# Out:
#                dateCrawled                                               name  \
# 0      2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1      2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2      2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3      2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4      2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
# 5      2016-03-21 13:47:45  Chrysler_Grand_Voyager_2.8_CRD_Aut.Limited_Sto...
# 6      2016-03-20 17:55:21  VW_Golf_III_GT_Special_Electronic_Green_Metall...
# 7      2016-03-16 18:55:19                               Golf_IV_1.9_TDI_90PS
# 8      2016-03-22 16:51:34                                         Seat_Arosa
# 9      2016-03-16 13:47:02          Renault_Megane_Scenic_1.6e_RT_Klimaanlage
# 10     2016-03-15 01:41:36                       VW_Golf_Tuning_in_siber/grau
# ...

# %%
autos.info()
autos.head()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 50000 entries, 0 to 49999
# Data columns (total 20 columns):
# dateCrawled            50000 non-null object
# name                   50000 non-null object
# seller                 50000 non-null object
# offerType              50000 non-null object
# price                  50000 non-null object
# abtest                 50000 non-null object
# vehicleType            44905 non-null object
# yearOfRegistration     50000 non-null int64
# gearbox                47320 non-null object
# powerPS                50000 non-null int64
# model                  47242 non-null object
# odometer               50000 non-null object
# monthOfRegistration    50000 non-null int64
# fuelType               45518 non-null object
# brand                  50000 non-null object
# notRepairedDamage      40171 non-null object
# dateCreated            50000 non-null object
# nrOfPictures           50000 non-null int64
# ...

# %% [markdown]
# After appling DataFrame.info() and DataFrame.head() methods on our data set, we are able to notice the following key points:
# 1) smth
# 2) smth

# %% [markdown]
# 1) The dataset contains 20 columns, most of which are strings (5 integer types and 15 object types(or strings)).
# 2)Some columns have null values, but none have more than ~20% null values.
# 3)The column names use camelcase instead of Python's preferred snakecase, which means we can't just replace spaces with underscores.

# %%
autos.columns
# Out:
# Index(['dateCrawled', 'name', 'seller', 'offerType', 'price', 'abtest',
#        'vehicleType', 'yearOfRegistration', 'gearbox', 'powerPS', 'model',
#        'odometer', 'monthOfRegistration', 'fuelType', 'brand',
#        'notRepairedDamage', 'dateCreated', 'nrOfPictures', 'postalCode',
#        'lastSeen'],
#       dtype='object')

# %%
autos.rename(columns={'yearOfRegistration': 'registration_year',
                     'monthOfRegistration': 'registration_month',
                     'notRepairedDamage': 'unrepaired_damage',
                     'dateCreated': 'ad_created',
                     'dateCrawled': 'ad_crawled',
                     'offerType': 'offer_type',
                     'vehicleType': 'vehicle_type',
                     'powerPS': 'power_ps',
                     'fuelType': 'fuel_type',
                     'nrOfPictures': 'number_of_pictures',
                     'postalCode': 'postal_code',
                     'lastSeen': 'last_seen_online'}, inplace=True)

# %%
autos.head()
# Out:
#             ad_crawled                                               name  \
# 0  2016-03-26 17:47:46                   Peugeot_807_160_NAVTECH_ON_BOARD
# 1  2016-04-04 13:38:56         BMW_740i_4_4_Liter_HAMANN_UMBAU_Mega_Optik
# 2  2016-03-26 18:57:24                         Volkswagen_Golf_1.6_United
# 3  2016-03-12 16:58:10  Smart_smart_fortwo_coupe_softouch/F1/Klima/Pan...
# 4  2016-04-01 14:38:50  Ford_Focus_1_6_Benzin_TÜV_neu_ist_sehr_gepfleg...
#
#    seller offer_type   price   abtest vehicle_type  registration_year  \
# 0  privat    Angebot  $5,000  control          bus               2004
# 1  privat    Angebot  $8,500  control    limousine               1997
# 2  privat    Angebot  $8,990     test    limousine               2009
# 3  privat    Angebot  $4,350  control   kleinwagen               2007
# 4  privat    Angebot  $1,350     test        kombi               2003
#
#      gearbox  power_ps   model   odometer  registration_month fuel_type  \
# ...

# %% [markdown]
# Write a markdown cell explaining the changes you made and why.

# %% [markdown]
# Now let's do some basic data exploration to determine what other cleaning tasks need to be done. Initially we will look for: - Text columns where all or almost all values are the same. These can often be dropped as they don't have useful information for analysis. - Examples of numeric data stored as text which can be cleaned and converted.

# %%
autos.describe()
# Out:
#        registration_year      power_ps  registration_month  \
# count       50000.000000  50000.000000        50000.000000
# mean         2005.073280    116.355920            5.723360
# std           105.712813    209.216627            3.711984
# min          1000.000000      0.000000            0.000000
# 25%          1999.000000     70.000000            3.000000
# 50%          2003.000000    105.000000            6.000000
# 75%          2008.000000    150.000000            9.000000
# max          9999.000000  17700.000000           12.000000
#
#        number_of_pictures   postal_code
# count             50000.0  50000.000000
# mean                  0.0  50813.627300
# std                   0.0  25779.747957
# min                   0.0   1067.000000
# 25%                   0.0  30451.000000
# 50%                   0.0  49577.000000
# 75%                   0.0  71540.000000
# max                   0.0  99998.000000

# %% [markdown]
# 1) Any columns that have mostly one value that are candidates to be dropped.
# 2) Any columns that need more investigation.
# 3) Any examples of numeric data stored as text that needs to be cleaned.

# %%
autos["price"].unique()
# Out:
# array(['$5,000', '$8,500', '$8,990', ..., '$385', '$22,200', '$16,995'],
#       dtype=object)

# %%
autos["odometer"].unique()
# Out:
# array(['150,000km', '70,000km', '50,000km', '80,000km', '10,000km',
#        '30,000km', '125,000km', '90,000km', '20,000km', '60,000km',
#        '5,000km', '100,000km', '40,000km'], dtype=object)

# %%
autos["price"] = autos["price"].str.replace('$','').str.replace(',','').astype(float)

# %%
autos["odometer_km"] = autos["odometer_km"].str.replace('km','').str.replace(',','').astype(float)

# %%
autos.rename(columns={'odometer': 'odometer_km'}, inplace=True)

# %% [markdown]
# # Exploring the Odometer and Price Columns

# %%
autos["odometer_km"].unique().shape
# Out:
# (13,)

# %%
autos["odometer_km"].describe()
# Out:
# count     50000.000000
# mean     125732.700000
# std       40042.211706
# min        5000.000000
# 25%      125000.000000
# 50%      150000.000000
# 75%      150000.000000
# max      150000.000000
# Name: odometer_km, dtype: float64

# %% [markdown]
# ### Series.describe() method also shows the number of unique values. Meaning that we do not need Series.unique().shape code above

# %%
autos["odometer_km"].value_counts()
# Out:
# 150000.0    32424
# 125000.0     5170
# 100000.0     2169
# 90000.0      1757
# 80000.0      1436
# 70000.0      1230
# 60000.0      1164
# 50000.0      1027
# 5000.0        967
# 40000.0       819
# 30000.0       789
# 20000.0       784
# 10000.0       264
# Name: odometer_km, dtype: int64

# %%
autos["price"].unique().shape
# Out:
# (2357,)

# %%
autos["price"].describe()
# Out:
# count    5.000000e+04
# mean     9.840044e+03
# std      4.811044e+05
# min      0.000000e+00
# 25%      1.100000e+03
# 50%      2.950000e+03
# 75%      7.200000e+03
# max      1.000000e+08
# Name: price, dtype: float64

# %%
autos["price"].value_counts().head()
# Out:
# 0.0       1421
# 500.0      781
# 1500.0     734
# 2500.0     643
# 1200.0     639
# Name: price, dtype: int64

# %%
autos["price"].sort_index().head()
# Out:
# 0    5000.0
# 1    8500.0
# 2    8990.0
# 3    4350.0
# 4    1350.0
# Name: price, dtype: float64

# %%
autos[autos["price"].between(1250, 1254)]
# Out:
#                 ad_crawled                                               name  \
# 306    2016-03-07 20:45:27                       FIAT_Punto_1_2_Klima__EURO_4
# 334    2016-03-14 09:51:24                                  Mercedes_a_Klasse
# 392    2016-03-25 13:57:30                          Trabant_601_L_mit_Papiere
# 473    2016-03-16 20:54:52  Polo_6N__fuer_wenig_Geld_und_Tuev_neu_bis_3/18...
# 507    2016-03-08 13:45:53                                      Citroën_Xsara
# 810    2016-04-03 14:46:47      Opel_Corsa_1.4_Sport_mit_TÜV_08/2016!!Euro4++
# 1245   2016-03-05 14:55:41  Renault_Clio_1.2_unfallfrei_2h.scheckh.d4_fahr...
# 1272   2016-03-19 11:50:36  Verkaufe_zuverlaessigen_VW_Golf_ohne_Reperatur...
# 1292   2016-03-25 20:48:07               Chevrolet_Matiz_Festpreis_1200_Euro!
# 1393   2016-04-02 23:57:17                                       Wartburg_353
# 1407   2016-03-10 17:38:44  Golf_3_Kombi_101PS_original_Zustand___unverbas...
# ...

# %% [markdown]
# # Exploring the Date columns

# %% [markdown]
# Right now, the date_crawled, last_seen, and ad_created columns are all identified as string values by pandas. Because these three columns are represented as strings, we need to convert the data into a numerical representation so we can understand it quantitatively. The other two columns are represented as numeric values, so we can use methods like Series.describe() to understand the distribution without any extra data processing.

# %% [markdown]
# Let's first understand how the values in the three string columns are formatted. These columns all represent full timestamp values, like so:

# %%
autos[['ad_crawled', 'ad_created', 'last_seen_online']][0:5]
# Out:
#             ad_crawled           ad_created     last_seen_online
# 0  2016-03-26 17:47:46  2016-03-26 00:00:00  2016-04-06 06:45:54
# 1  2016-04-04 13:38:56  2016-04-04 00:00:00  2016-04-06 14:45:08
# 2  2016-03-26 18:57:24  2016-03-26 00:00:00  2016-04-06 20:15:37
# 3  2016-03-12 16:58:10  2016-03-12 00:00:00  2016-03-15 03:16:28
# 4  2016-04-01 14:38:50  2016-04-01 00:00:00  2016-04-01 14:38:50
